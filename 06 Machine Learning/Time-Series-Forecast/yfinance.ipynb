# %%
# !pip install yfinance  # install yahoo finance package

# %%
import yfinance as yf
# Define the ticker symbol and time period
ticker_symbol = 'M&M.NS'  # Mahindra Stock symbol
start_date = '2020-01-01'
end_date = '2024-11-10'  # 'yyyy-mm-dd' e.g '2024-10-25'
# Download data
data = yf.download(ticker_symbol, start=start_date, end=end_date)
# Display the data
data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                        Adj Close        Close         High          Low  \
# Ticker                          M&M.NS       M&M.NS       M&M.NS       M&M.NS
# Date
# 2024-11-04 00:00:00+00:00  2883.949951  2883.949951  2971.750000  2804.500000
# 2024-11-05 00:00:00+00:00  2899.449951  2899.449951  2908.000000  2822.100098
# 2024-11-06 00:00:00+00:00  2934.550049  2934.550049  2953.800049  2885.399902
# 2024-11-07 00:00:00+00:00  2891.350098  2891.350098  2972.550049  2857.949951
# 2024-11-08 00:00:00+00:00  2974.899902  2974.899902  2990.949951  2851.250000
#
# Price                         Open   Volume
# Ticker                      M&M.NS   M&M.NS
# Date
# 2024-11-04 00:00:00+00:00  2804.50  7559263
# 2024-11-05 00:00:00+00:00  2875.50  3562624
# 2024-11-06 00:00:00+00:00  2910.00  2902347
# 2024-11-07 00:00:00+00:00  2971.75  4251557
# 2024-11-08 00:00:00+00:00  2910.00  4455563
